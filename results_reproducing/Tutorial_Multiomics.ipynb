# %% [markdown]
# # Fine-tuning on Pre-trained Model for Multiomic Integration
# In this tutorial, we demonstrate how to fine-tune a pre-trained model for multiomic integration. We use the BMMC dataset as an example for RNA and protein abundance data integration from CITE-seq. The BMMC dataset consists of multiple batches by donor origin. In the paired integration setting, each cell contains both RNA and protein measurements. We fine-tune on the pre-trained whole-body model.
#
# We summarize the fine-tuning pipeline in the following steps, which can be used as a general recipe for finetuning on integration tasks and beyond:
#
#      1. Specify hyper-parameter setup for integration task
#
#      2. Load and pre-process data
#
#      3. Load the pre-trained scGPT model
#
#      4. Finetune scGPT with task-specific objectives
#
#      5. Evaluate fine-tuned scGPT
#
#
# https://frontlinegenomics.com/a-guide-to-multi-omics-integration-strategies/

# %%
import copy
import gc
import json
import os
from pathlib import Path
import sys
import time
import traceback
#from typing import List, Tuple, Dict, Union, Optional
import warnings

import torch
from anndata import AnnData
import scanpy as sc
import scvi
import numpy as np
import wandb
from scipy.sparse import issparse
import matplotlib.pyplot as plt
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)
import pandas as pd
import scipy.sparse as sp
from sklearn import preprocessing

sys.path.insert(0, "../")
from scgpt import prepare_data, prepare_dataloader, define_wandb_metrcis, evaluate, eval_testdata, train
from scgpt.tokenizer import tokenize_and_pad_batch
from scgpt.model import MultiOmicTransformerModel

import scgpt as scg
from scgpt.tokenizer.gene_tokenizer import GeneVocab
from scgpt.tokenizer import random_mask_value
from scgpt.loss import (
    masked_mse_loss,
    masked_relative_error,
    criterion_neg_log_bernoulli,
)
from scgpt.preprocess import Preprocessor
from scgpt.utils import set_seed, category_str2int, eval_scib_metrics

sc.set_figure_params(figsize=(4, 4))
os.environ["KMP_WARNINGS"] = "off"
warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /disk/10tb/home/kuzmina/anaconda3/envs/scgpt_2/lib/python3.10/site-packages/scanpy/_settings.py:488: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   IPython.display.set_matplotlib_formats(*ipython_format)
# /disk/10tb/home/kuzmina/anaconda3/envs/scgpt_2/lib/python3.10/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(

# %% [markdown]
# ## Step1: Specify hyper-parameter setup for integration task
# Here we provide some hyper-parameter recommendations for the multiomic integration task. Note that the BMMC dataset contains multiple batches to be integrated. Therefore, in addition to the default gene modelling objectives, we also turn on DAR objectives specifically to faciliate batch integration. We also turn on the use_mod argument as default to ensure that the model is modality-aware during training.

# %%
hyperparameter_defaults = dict(
    task = 'multiomic',
    seed=42,
    dataset_name="BMMC", # Dataset name
    do_train=True, # Flag to indicate whether to do update model parameters during training
    load_model="save/scGPT_human", # Path to pre-trained model
    freeze = False, #freeze
    GEP=True, # Gene expression modelling
    GEPC=True, # Gene expression modelling for cell objective
    CLS=False,
    ESC=False,
    DAR = True, # DAR objective weight for batch correction
    DSBN = False,  # Domain-spec batchnorm,
    mask_ratio=0.4, # Default mask ratio
    explicit_zero_prob = False,  # whether explicit bernoulli for zeros
    ecs_thres=0,  # Elastic cell similarity objective, 0.0 to 1.0, 0.0 to disable
    dab_weight=1.0,
    use_batch_labels = True,
    use_mod = True,
    per_seq_batch_sample = False,
    epochs=25, # Default number of epochs for fine-tuning
    input_layer_key = "X_binned", # Default expression value binning in data pre-processing
    n_bins=51, # Default number of bins for value binning in data pre-processing
    n_hvg = 1200,  # Default number of highly variable genes
    n_hvp = 4000,
    max_seq_len = 4001, # # Default n_hvg+1
    lr=1e-3, # Default learning rate for fine-tuning
    batch_size=16, # Default batch size for fine-tuning
    layer_size=512,
    nlayers=4,
    nhead=8, # if load model, batch_size, layer_size, nlayers, nhead will be ignored
    dropout=0.2, # Default dropout rate during model fine-tuning
    schedule_ratio=0.95,  # Default rate for learning rate decay
    save_eval_interval=5, # Default model evaluation interval

    log_interval=100, # Default log interval
    
    # fast_transformer=True, # Default setting
    fast_transformer=False,
    
    pre_norm=False, # Default setting
    amp=True,  # Default setting: Automatic Mixed Precision
    pad_token = "<pad>",
    mask_value = -1,
    pad_value = -2,
    include_zero_gene = False,
)

# %%
run = wandb.init(
    config=hyperparameter_defaults,
    project="scGPT",
    reinit=True,
    settings=wandb.Settings(start_method="fork"),
)
config = wandb.config
print(config)

set_seed(config.seed)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: kuzmina7748. Use `wandb login --relogin` to force relogin
# wandb version 0.17.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/disk/10tb/home/kuzmina/omics_gene/wandb/run-20240509_094211-j3gn7n7v</code>
# Syncing run <strong><a href='https://wandb.ai/kuzmina7748/scGPT/runs/j3gn7n7v' target="_blank">lilac-gorge-11</a></strong> to <a href='https://wandb.ai/kuzmina7748/scGPT' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/kuzmina7748/scGPT' target="_blank">https://wandb.ai/kuzmina7748/scGPT</a>
#  View run at <a href='https://wandb.ai/kuzmina7748/scGPT/runs/j3gn7n7v' target="_blank">https://wandb.ai/kuzmina7748/scGPT/runs/j3gn7n7v</a>
# {'task': 'multiomic', 'seed': 42, 'dataset_name': 'BMMC', 'do_train': True, 'load_model': 'save/scGPT_human', 'freeze': False, 'GEP': True, 'GEPC': True, 'CLS': False, 'ESC': False, 'DAR': True, 'DSBN': False, 'mask_ratio': 0.4, 'explicit_zero_prob': False, 'ecs_thres': 0, 'dab_weight': 1.0, 'use_batch_labels': True, 'use_mod': True, 'per_seq_batch_sample': False, 'epochs': 25, 'input_layer_key': 'X_binned', 'n_bins': 51, 'n_hvg': 1200, 'n_hvp': 4000, 'max_seq_len': 4001, 'lr': 0.001, 'batch_size': 16, 'layer_size': 512, 'nlayers': 4, 'nhead': 8, 'dropout': 0.2, 'schedule_ratio': 0.95, 'save_eval_interval': 5, 'log_interval': 100, 'fast_transformer': False, 'pre_norm': False, 'amp': True, 'pad_token': '<pad>', 'mask_value': -1, 'pad_value': -2, 'include_zero_gene': False}

# %%
# settings for input and preprocessing
special_tokens = [config.pad_token, "<cls>", "<eoc>"]

# %%
dataset_name = config.dataset_name
save_dir = Path(f"./save/dev_{dataset_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"save to {save_dir}")
logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")
# Out:
# save to save/dev_BMMC-May09-09-42

# %% [markdown]
# ## Step 2: Load and pre-process data

# %% [markdown]
# ### 2.1 Load the BMMC data
# Please download the data from https://drive.google.com/file/d/10RxboePS5p2Jj2Sfq1Ghzgqnl6nqPv5V/view?usp=sharing
#
# For the purpose of this tutorial, we selected a 12K+ cell subset from the BMMC dataset (originally 90K+ cells) to speed up training. More specifically, we filtered on the first 3 donors (batches) with B, Mono and T cell subtypes as shown in the data loading step below.

# %%
if dataset_name == 'BMMC':
    adata = sc.read('BMMC_processed.h5ad')
    # subset to first 3 donors with B, Mono and T cell subtypes
    adata = adata[adata.obs.DonorID.isin([10886, 11466, 12710]) & adata.obs.cell_type.isin(np.unique(adata.obs.cell_type.values)[:17])]
    adata.obs["celltype"] = adata.obs["cell_type"].astype(str).astype('category')
    adata.var["gene_name"] = adata.var.index.tolist()
    le = preprocessing.LabelEncoder()
    encoded_batch = le.fit_transform(adata.obs['batch'].values)
    adata.obs["batch_id"] =  encoded_batch
    adata.obs["str_batch"] = adata.obs["batch_id"].astype('category')
    adata_protein = adata[:, adata.var.feature_types.isin(['ADT'])].copy()
    adata_protein.var.index = ['p_' + i for i in adata_protein.var.index]
    adata = adata[:, adata.var.feature_types.isin(['GEX'])].copy()
    data_is_raw = False

# %%
if config.use_mod:
    gene_rna_df = pd.DataFrame(index = adata.var.index.tolist())
    gene_rna_df['mod'] = 'RNA'
    gene_protein_df = pd.DataFrame(index = adata_protein.var.index.tolist())
    gene_protein_df['mod'] = 'Protein'
    gene_loc_df = pd.concat([gene_rna_df, gene_protein_df])
    gene_loc_df['mod'] = gene_loc_df['mod'].astype('category')

# %% [markdown]
# ### 2.2 Cross-check gene set with the pre-trained model
# Note that we retain the common gene set between the data and the pre-trained model for further fine-tuning.

# %%
if config.load_model is not None:
    model_dir = Path(config.load_model)
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    old_vocab = vocab
embsize = config.layer_size
nhead = config.nhead
nlayers = config.nlayers
d_hid = config.layer_size
# Out:
# scGPT - INFO - match 12587/13953 genes in vocabulary of size 60697.

# %% [markdown]
# ### 2.3 Pre-process the data
# We follow the standardized pipline of depth normalization, log normalization, and highly vairable gene (HVG) selection for data pre-processing. We further introduce value binning to obtain the relative expressions of each HVG. Given multiple sequencing modalities, we perform the pre-processing steps on each individual modality first, and then combine them into multi-modal sequences as model input.

# %% [markdown]
# #### 2.3.1 Pre-process the RNA data

# %%
preprocessor = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=1,  # step 1
    filter_cell_by_counts=1,  # step 2
    normalize_total=1e4,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=data_is_raw,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=config.n_hvg,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor="seurat_v3" if data_is_raw else "cell_ranger",
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor(adata, batch_key=None)
# Out:
# scGPT - INFO - Filtering genes by counts ...
# scGPT - INFO - Filtering cells by counts ...
# scGPT - INFO - Normalizing total counts ...
# scGPT - INFO - Subsetting highly variable genes ...
# scGPT - WARNING - No batch_key is provided, will use all cells for HVG selection.
# scGPT - INFO - Binning data ...

# %% [markdown]
# #### 2.3.2 Pre-process the Protein data

# %%
preprocessor_protein = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=0,  # step 1
    filter_cell_by_counts=False,  # step 2
    normalize_total=False,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=False,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=False,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor=None,
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor_protein(adata_protein, batch_key=None)
# Out:
# scGPT - INFO - Binning data ...

# %% [markdown]
# #### 2.3.3 Combine RNA, and Protein data

# %%
data_combined = np.concatenate([adata.layers["X_binned"], adata_protein.layers["X_binned"]], axis=1)
adata = AnnData(
    X=data_combined,
    obs=adata.obs,
    var=pd.DataFrame(index=adata.var_names.tolist() + adata_protein.var_names.tolist()),
    layers={"X_binned": data_combined,}
)
adata.var["gene_name"] = adata.var.index.tolist()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12578 × 1334
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'celltype', 'batch_id', 'str_batch', 'n_counts'
#     var: 'gene_name'
#     layers: 'X_binned'

# %%
if config.per_seq_batch_sample:
    # sort the adata by batch_id in advance
    adata_sorted = adata[adata.obs["batch_id"].argsort()].copy()

# %% [markdown]
# ### 2.4 Tokenize the input data for model fine-tuning

# %%
all_counts = (
    adata.layers[config.input_layer_key].A
    if issparse(adata.layers[config.input_layer_key])
    else adata.layers[config.input_layer_key]
)
genes = adata.var["gene_name"].tolist()

celltypes_labels = adata.obs["celltype"].tolist()  # make sure count from 0
num_types = len(set(celltypes_labels))
celltypes_labels = np.array(celltypes_labels)

batch_ids = adata.obs["batch_id"].tolist()
num_batch_types = len(set(batch_ids))
batch_ids = np.array(batch_ids)

# %%
if config.use_mod:
    mod_type = np.array([gene_loc_df.loc[g, 'mod'] for g in genes])
    vocab_mod = Vocab(VocabPybind(np.unique(gene_loc_df['mod']).tolist() + special_tokens, None))
    vocab_mod.set_default_index(vocab_mod["<pad>"])
    mod_type = np.array(vocab_mod(list(mod_type)), dtype=int)
    ntokens_mod = len(vocab_mod)

# %%
(
    train_data,
    valid_data,
    train_celltype_labels,
    valid_celltype_labels,
    train_batch_labels,
    valid_batch_labels,
) = train_test_split(
    all_counts, celltypes_labels, batch_ids, test_size=0.1, shuffle=True
)

# %%
num_of_non_zero_genes = [
    np.count_nonzero(train_data[i]) for i in range(train_data.shape[0])
]
print(f"max num of non_zero genes: {np.max(num_of_non_zero_genes)}")
print(f"min num of non_zero genes: {np.min(num_of_non_zero_genes)}")
print(f"average num of non_zero genes: {np.mean(num_of_non_zero_genes)}")
print(
    f"99% quantile num of non_zero genes: {np.quantile(num_of_non_zero_genes, 0.99)}"
)
print(f"max original values: {np.max(train_data)}")
print(
    f"average original non_zero values: {np.mean(train_data[np.nonzero(train_data)])}"
)
print(
    f"99% quantile original non_zero values: {np.quantile(train_data[np.nonzero(train_data)], 0.99)}"
)
print(f"num of celltypes: {num_types}")
# Out:
# max num of non_zero genes: 687
# min num of non_zero genes: 206
# average num of non_zero genes: 341.5295053003534
# 99% quantile num of non_zero genes: 510.0
# max original values: 50
# average original non_zero values: 25.3482856428962
# 99% quantile original non_zero values: 49.0
# num of celltypes: 17

# %%
if config.load_model is None:
    vocab = Vocab(VocabPybind(genes + special_tokens, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)
else:
    pretrained_genes = [g for g in genes + special_tokens if g in old_vocab]
    new_genes = [g for g in genes + special_tokens if g not in old_vocab]
    gene_ids_pretrained = np.array(old_vocab(pretrained_genes), dtype=int)
    # https://discuss.pytorch.org/t/expand-an-existing-embedding-and-linear-layer-nan-loss-value/55670/2
    # Retrieve pretrained weights
    vocab = Vocab(VocabPybind(pretrained_genes + new_genes, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)

# %%
tokenized_train = tokenize_and_pad_batch(
    train_data,
    gene_ids,
    max_len=config.max_seq_len,
    vocab=vocab,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    append_cls=True,  # append <cls> token at the beginning
    include_zero_gene=config.include_zero_gene,
    mod_type=mod_type if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)
tokenized_valid = tokenize_and_pad_batch(
    valid_data,
    gene_ids,
    max_len=config.max_seq_len,
    vocab=vocab,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    append_cls=True,
    include_zero_gene=config.include_zero_gene,
    mod_type=mod_type if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)
logger.info(
    f"train set number of samples: {tokenized_train['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_train['genes'].shape[1]}"
)
logger.info(
    f"valid set number of samples: {tokenized_valid['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_valid['genes'].shape[1]}"
)
# Out:
# scGPT - INFO - train set number of samples: 11320,
# 	 feature length: 688
# scGPT - INFO - valid set number of samples: 1258,
# 	 feature length: 663

# %% [markdown]
# ## Step 3: Load the pre-trained scGPT model
# Note that for multiomic integration, since the pre-trained model does not include the ATAC and protein tokens, we expand the embedding layer by adding these new tokens. We inherit only the gene embedding layer from the pre-trained model, and train rest of the model from scratch.

# %%
torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# device(type='cuda')

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_dict = torch.load(model_file)
ntokens = len(vocab)  # size of vocabulary
model = MultiOmicTransformerModel(
    ntokens,
    embsize,
    nhead,
    d_hid, 
    nlayers,
    vocab=vocab,
    dropout=config.dropout,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    do_mvc=config.GEPC,
    do_dab=config.DAR,
    use_batch_labels=config.use_batch_labels,
    num_batch_labels=num_batch_types,
    domain_spec_batchnorm=config.DSBN,
    n_input_bins=config.n_bins,
    ecs_threshold=config.ecs_thres,
    explicit_zero_prob=config.explicit_zero_prob,
    use_fast_transformer=config.fast_transformer,
    pre_norm=config.pre_norm,
    use_mod=config.use_mod,
    ntokens_mod=ntokens_mod if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)

with torch.no_grad():
    pretrained_emb_weights = model_dict['encoder.embedding.weight'][gene_ids_pretrained, :]
    model.encoder.embedding.weight.data[:len(pretrained_genes), :] = pretrained_emb_weights
    model.encoder.enc_norm.weight.data = model_dict['encoder.enc_norm.weight']
ntokens = len(vocab)

model.to(device)
wandb.watch(model)
print(model)
# Out:
# MultiOmicTransformerModel(
#   (encoder): GeneEncoder(
#     (embedding): Embedding(1337, 512, padding_idx=1089)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (value_encoder): ContinuousValueEncoder(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (linear1): Linear(in_features=1, out_features=512, bias=True)
#     (activation): ReLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (batch_encoder): BatchLabelEncoder(
#     (embedding): Embedding(3, 512)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (mod_encoder): BatchLabelEncoder(
#     (embedding): Embedding(5, 512, padding_idx=2)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (decoder): ExprDecoder(
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
#   (cls_decoder): ClsDecoder(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): ReLU()
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=1, bias=True)
#   )
#   (mvc_decoder): MVCDecoder(
#     (gene2query): Linear(in_features=1024, out_features=1024, bias=True)
#     (query_activation): Sigmoid()
#     (W): Linear(in_features=1024, out_features=1024, bias=False)
#   )
#   (grad_reverse_discriminator): AdversarialDiscriminator(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=3, bias=True)
#   )
#   (sim): Similarity(
#     (cos): CosineSimilarity()
#   )
#   (creterion_cce): CrossEntropyLoss()
# )

# %%
if config.GEP and config.GEPC:
    criterion_gep_gepc = masked_mse_loss
if config.CLS:
    criterion_cls = nn.CrossEntropyLoss()
if config.DAR:
    criterion_dab = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=config.lr, eps=1e-4 if config.amp else 1e-8
)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=config.schedule_ratio)
scaler = torch.cuda.amp.GradScaler(enabled=config.amp)

# %% [markdown]
# ## Step 4: Finetune scGPT with task-specific objectives

# %%
best_val_loss = float("inf")
best_avg_bio = 0.0
best_model = None
define_wandb_metrcis()

for epoch in range(1, config.epochs + 1):
    epoch_start_time = time.time()
    train_data_pt, valid_data_pt = prepare_data(
        tokenized_train=tokenized_train, 
        tokenized_valid=tokenized_valid, 
        train_batch_labels=train_batch_labels,
        valid_batch_labels=valid_batch_labels,
        config=config,
        epoch=epoch,
        sort_seq_batch=config.per_seq_batch_sample)
    
    train_loader = prepare_dataloader(
        train_data_pt,
        batch_size=config.batch_size,
        shuffle=True,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config.per_seq_batch_sample
    )
    valid_loader = prepare_dataloader(
        valid_data_pt,
        batch_size=config.batch_size,
        shuffle=False,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config.per_seq_batch_sample
    )

    if config.do_train:
        train(
            model=model,
            loader=train_loader,
            vocab=vocab,
            criterion_gep_gepc=criterion_gep_gepc if config.GEP and config.GEPC else None,
            criterion_dab=criterion_dab if config.DAR else None,
            criterion_cls=criterion_cls if config.CLS else None,
            scaler=scaler,
            optimizer=optimizer,
            scheduler=scheduler,
            device=device,
            config=config,
            logger=logger,
            epoch=epoch,
        )
    val_loss = evaluate(
        model=model,
        loader=valid_loader,
        vocab=vocab,
        criterion_gep_gepc=criterion_gep_gepc if config.GEP and config.GEPC else None,
        criterion_dab=criterion_dab if config.DAR else None,
        criterion_cls=criterion_cls if config.CLS else None,
        device=device,
        config=config,
        epoch=epoch
    )
    elapsed = time.time() - epoch_start_time
    logger.info("-" * 89)
    logger.info(
        f"| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | "
        f"valid loss {val_loss:5.4f} | "
    )
    logger.info("-" * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        best_model_epoch = epoch
        logger.info(f"Best model with score {best_val_loss:5.4f}")

    if epoch % config.save_eval_interval == 0 or epoch == config.epochs:
        logger.info(f"Saving model to {save_dir}")
        torch.save(best_model.state_dict(), save_dir / f"model_e{best_model_epoch}.pt")

        # eval on testdata
        results = eval_testdata(
            model = best_model,
            adata_t = adata_sorted if config.per_seq_batch_sample else adata,
            gene_ids = gene_ids,
            vocab = vocab,
            config = config,
            logger = logger,
            include_types=["cls"],
        )
        results["batch_umap"].savefig(
            save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png", dpi=300
        )

        results["celltype_umap"].savefig(
            save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png", dpi=300
        )
        metrics_to_log = {"test/" + k: v for k, v in results.items()}
        metrics_to_log["test/batch_umap"] = wandb.Image(
            str(save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )

        metrics_to_log["test/celltype_umap"] = wandb.Image(
            str(save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )
        metrics_to_log["test/best_model_epoch"] = best_model_epoch
        wandb.log(metrics_to_log)
        wandb.log({"avg_bio": results.get("avg_bio", 0.0)})

    scheduler.step()
# Out:
# random masking at epoch   1, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   1 | 100/708 batches | lr 0.00100 | ms/batch 68.33 | loss 11218.64 | gep 379.42 |gepc 10838.05 |dar  1.16 |
# scGPT - INFO - | epoch   1 | 200/708 batches | lr 0.00100 | ms/batch 63.00 | loss 279.54 | gep 202.41 |gepc 76.12 |dar  1.01 |
# scGPT - INFO - | epoch   1 | 300/708 batches | lr 0.00100 | ms/batch 63.03 | loss 277.93 | gep 201.53 |gepc 75.43 |dar  0.97 |
# scGPT - INFO - | epoch   1 | 400/708 batches | lr 0.00100 | ms/batch 63.22 | loss 278.72 | gep 202.14 |gepc 75.59 |dar  0.98 |
# scGPT - INFO - | epoch   1 | 500/708 batches | lr 0.00100 | ms/batch 62.97 | loss 276.18 | gep 201.93 |gepc 73.26 |dar  0.98 |
# scGPT - INFO - | epoch   1 | 600/708 batches | lr 0.00100 | ms/batch 62.95 | loss 276.02 | gep 200.91 |gepc 74.11 |dar  1.00 |
# scGPT - INFO - | epoch   1 | 700/708 batches | lr 0.00100 | ms/batch 62.99 | loss 276.53 | gep 202.30 |gepc 73.26 |dar  0.96 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   1 | time: 46.95s | valid loss 201.3547 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 201.3547
# random masking at epoch   2, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   2 | 100/708 batches | lr 0.00095 | ms/batch 63.54 | loss 278.43 | gep 203.69 |gepc 73.77 |dar  0.97 |
# scGPT - INFO - | epoch   2 | 200/708 batches | lr 0.00095 | ms/batch 63.17 | loss 276.08 | gep 202.28 |gepc 72.82 |dar  0.98 |
# scGPT - INFO - | epoch   2 | 300/708 batches | lr 0.00095 | ms/batch 63.67 | loss 275.09 | gep 201.99 |gepc 72.16 |dar  0.94 |
# scGPT - INFO - | epoch   2 | 400/708 batches | lr 0.00095 | ms/batch 63.11 | loss 256.72 | gep 180.66 |gepc 75.08 |dar  0.99 |
# scGPT - INFO - | epoch   2 | 500/708 batches | lr 0.00095 | ms/batch 63.16 | loss 158.03 | gep 85.18 |gepc 71.92 |dar  0.93 |
# scGPT - INFO - | epoch   2 | 600/708 batches | lr 0.00095 | ms/batch 63.21 | loss 138.41 | gep 71.81 |gepc 65.75 |dar  0.85 |
# scGPT - INFO - | epoch   2 | 700/708 batches | lr 0.00095 | ms/batch 63.20 | loss 128.77 | gep 66.92 |gepc 61.03 |dar  0.82 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   2 | time: 46.60s | valid loss 64.4130 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 64.4130
# random masking at epoch   3, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   3 | 100/708 batches | lr 0.00090 | ms/batch 63.92 | loss 126.27 | gep 64.84 |gepc 60.59 |dar  0.84 |
# scGPT - INFO - | epoch   3 | 200/708 batches | lr 0.00090 | ms/batch 63.06 | loss 125.56 | gep 63.93 |gepc 60.84 |dar  0.79 |
# scGPT - INFO - | epoch   3 | 300/708 batches | lr 0.00090 | ms/batch 63.25 | loss 124.39 | gep 63.20 |gepc 60.39 |dar  0.80 |
# scGPT - INFO - | epoch   3 | 400/708 batches | lr 0.00090 | ms/batch 63.08 | loss 122.54 | gep 61.94 |gepc 59.81 |dar  0.79 |
# scGPT - INFO - | epoch   3 | 500/708 batches | lr 0.00090 | ms/batch 63.31 | loss 123.92 | gep 62.60 |gepc 60.53 |dar  0.79 |
# scGPT - INFO - | epoch   3 | 600/708 batches | lr 0.00090 | ms/batch 63.89 | loss 120.56 | gep 60.90 |gepc 58.93 |dar  0.72 |
# scGPT - INFO - | epoch   3 | 700/708 batches | lr 0.00090 | ms/batch 63.21 | loss 120.43 | gep 60.54 |gepc 59.15 |dar  0.74 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   3 | time: 46.68s | valid loss 59.9571 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 59.9571
# random masking at epoch   4, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   4 | 100/708 batches | lr 0.00086 | ms/batch 63.97 | loss 121.43 | gep 61.06 |gepc 59.59 |dar  0.78 |
# scGPT - INFO - | epoch   4 | 200/708 batches | lr 0.00086 | ms/batch 62.88 | loss 117.09 | gep 58.66 |gepc 57.68 |dar  0.75 |
# scGPT - INFO - | epoch   4 | 300/708 batches | lr 0.00086 | ms/batch 63.06 | loss 117.65 | gep 58.80 |gepc 58.09 |dar  0.76 |
# scGPT - INFO - | epoch   4 | 400/708 batches | lr 0.00086 | ms/batch 62.97 | loss 116.10 | gep 57.92 |gepc 57.44 |dar  0.74 |
# scGPT - INFO - | epoch   4 | 500/708 batches | lr 0.00086 | ms/batch 62.97 | loss 115.30 | gep 57.55 |gepc 56.97 |dar  0.78 |
# scGPT - INFO - | epoch   4 | 600/708 batches | lr 0.00086 | ms/batch 63.15 | loss 116.58 | gep 57.97 |gepc 57.88 |dar  0.74 |
# scGPT - INFO - | epoch   4 | 700/708 batches | lr 0.00086 | ms/batch 63.12 | loss 115.39 | gep 57.48 |gepc 57.15 |dar  0.76 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   4 | time: 46.53s | valid loss 56.6197 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 56.6197
# random masking at epoch   5, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   5 | 100/708 batches | lr 0.00081 | ms/batch 63.82 | loss 113.10 | gep 56.30 |gepc 56.06 |dar  0.74 |
# scGPT - INFO - | epoch   5 | 200/708 batches | lr 0.00081 | ms/batch 63.58 | loss 112.46 | gep 55.84 |gepc 55.84 |dar  0.77 |
# scGPT - INFO - | epoch   5 | 300/708 batches | lr 0.00081 | ms/batch 63.23 | loss 113.33 | gep 56.55 |gepc 56.02 |dar  0.76 |
# scGPT - INFO - | epoch   5 | 400/708 batches | lr 0.00081 | ms/batch 63.15 | loss 112.53 | gep 55.96 |gepc 55.85 |dar  0.72 |
# scGPT - INFO - | epoch   5 | 500/708 batches | lr 0.00081 | ms/batch 63.01 | loss 113.13 | gep 56.33 |gepc 56.07 |dar  0.74 |
# scGPT - INFO - | epoch   5 | 600/708 batches | lr 0.00081 | ms/batch 62.98 | loss 110.75 | gep 55.14 |gepc 54.91 |dar  0.70 |
# scGPT - INFO - | epoch   5 | 700/708 batches | lr 0.00081 | ms/batch 62.98 | loss 109.84 | gep 54.55 |gepc 54.61 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   5 | time: 46.57s | valid loss 55.6679 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 55.6679
# scGPT - INFO - Saving model to save/dev_BMMC-May09-09-42
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████| 787/787 [00:15<00:00, 52.41it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.626559
# ARI_cluster/label          0.651715
# ASW_label                  0.648510
# ASW_label/batch            0.797657
# PCR_batch                  0.156631
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.773824
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6485, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.1566, ASW (batch): 0.7977, graph connectivity: 0.7738, graph iLISI: nan
# random masking at epoch   6, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   6 | 100/708 batches | lr 0.00077 | ms/batch 63.91 | loss 113.00 | gep 56.05 |gepc 56.19 |dar  0.76 |
# scGPT - INFO - | epoch   6 | 200/708 batches | lr 0.00077 | ms/batch 63.26 | loss 108.39 | gep 53.60 |gepc 54.08 |dar  0.71 |
# scGPT - INFO - | epoch   6 | 300/708 batches | lr 0.00077 | ms/batch 63.57 | loss 110.55 | gep 54.87 |gepc 54.97 |dar  0.71 |
# scGPT - INFO - | epoch   6 | 400/708 batches | lr 0.00077 | ms/batch 63.70 | loss 110.23 | gep 54.54 |gepc 55.00 |dar  0.69 |
# scGPT - INFO - | epoch   6 | 500/708 batches | lr 0.00077 | ms/batch 64.39 | loss 108.37 | gep 53.56 |gepc 54.09 |dar  0.72 |
# scGPT - INFO - | epoch   6 | 600/708 batches | lr 0.00077 | ms/batch 63.56 | loss 109.83 | gep 54.41 |gepc 54.72 |dar  0.70 |
# scGPT - INFO - | epoch   6 | 700/708 batches | lr 0.00077 | ms/batch 63.33 | loss 107.95 | gep 53.48 |gepc 53.80 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   6 | time: 46.86s | valid loss 53.7249 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 53.7249
# random masking at epoch   7, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   7 | 100/708 batches | lr 0.00074 | ms/batch 64.09 | loss 107.68 | gep 53.23 |gepc 53.73 |dar  0.72 |
# scGPT - INFO - | epoch   7 | 200/708 batches | lr 0.00074 | ms/batch 63.09 | loss 109.16 | gep 54.00 |gepc 54.48 |dar  0.68 |
# scGPT - INFO - | epoch   7 | 300/708 batches | lr 0.00074 | ms/batch 63.57 | loss 106.39 | gep 52.65 |gepc 53.06 |dar  0.69 |
# scGPT - INFO - | epoch   7 | 400/708 batches | lr 0.00074 | ms/batch 63.24 | loss 108.33 | gep 53.62 |gepc 54.03 |dar  0.68 |
# scGPT - INFO - | epoch   7 | 500/708 batches | lr 0.00074 | ms/batch 63.22 | loss 108.32 | gep 53.69 |gepc 53.97 |dar  0.66 |
# scGPT - INFO - | epoch   7 | 600/708 batches | lr 0.00074 | ms/batch 63.55 | loss 107.59 | gep 53.19 |gepc 53.71 |dar  0.69 |
# scGPT - INFO - | epoch   7 | 700/708 batches | lr 0.00074 | ms/batch 63.25 | loss 107.26 | gep 53.10 |gepc 53.47 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   7 | time: 46.69s | valid loss 55.1720 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch   8, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   8 | 100/708 batches | lr 0.00070 | ms/batch 64.51 | loss 107.04 | gep 52.96 |gepc 53.39 |dar  0.68 |
# scGPT - INFO - | epoch   8 | 200/708 batches | lr 0.00070 | ms/batch 63.09 | loss 106.61 | gep 52.65 |gepc 53.30 |dar  0.67 |
# scGPT - INFO - | epoch   8 | 300/708 batches | lr 0.00070 | ms/batch 63.16 | loss 106.62 | gep 52.77 |gepc 53.18 |dar  0.68 |
# scGPT - INFO - | epoch   8 | 400/708 batches | lr 0.00070 | ms/batch 63.32 | loss 107.56 | gep 53.24 |gepc 53.63 |dar  0.69 |
# scGPT - INFO - | epoch   8 | 500/708 batches | lr 0.00070 | ms/batch 63.34 | loss 105.76 | gep 52.29 |gepc 52.76 |dar  0.71 |
# scGPT - INFO - | epoch   8 | 600/708 batches | lr 0.00070 | ms/batch 63.30 | loss 107.04 | gep 53.05 |gepc 53.32 |dar  0.67 |
# scGPT - INFO - | epoch   8 | 700/708 batches | lr 0.00070 | ms/batch 63.17 | loss 105.72 | gep 52.33 |gepc 52.73 |dar  0.65 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   8 | time: 46.69s | valid loss 52.0161 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 52.0161
# random masking at epoch   9, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   9 | 100/708 batches | lr 0.00066 | ms/batch 63.98 | loss 105.71 | gep 52.18 |gepc 52.82 |dar  0.71 |
# scGPT - INFO - | epoch   9 | 200/708 batches | lr 0.00066 | ms/batch 63.20 | loss 106.47 | gep 52.56 |gepc 53.22 |dar  0.69 |
# scGPT - INFO - | epoch   9 | 300/708 batches | lr 0.00066 | ms/batch 63.25 | loss 104.50 | gep 51.71 |gepc 52.11 |dar  0.68 |
# scGPT - INFO - | epoch   9 | 400/708 batches | lr 0.00066 | ms/batch 63.83 | loss 105.74 | gep 52.24 |gepc 52.82 |dar  0.69 |
# scGPT - INFO - | epoch   9 | 500/708 batches | lr 0.00066 | ms/batch 63.18 | loss 105.96 | gep 52.40 |gepc 52.91 |dar  0.66 |
# scGPT - INFO - | epoch   9 | 600/708 batches | lr 0.00066 | ms/batch 63.06 | loss 103.47 | gep 51.16 |gepc 51.64 |dar  0.66 |
# scGPT - INFO - | epoch   9 | 700/708 batches | lr 0.00066 | ms/batch 63.24 | loss 105.05 | gep 51.89 |gepc 52.49 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   9 | time: 46.67s | valid loss 52.9819 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  10, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  10 | 100/708 batches | lr 0.00063 | ms/batch 63.89 | loss 106.80 | gep 52.75 |gepc 53.36 |dar  0.69 |
# scGPT - INFO - | epoch  10 | 200/708 batches | lr 0.00063 | ms/batch 63.36 | loss 104.74 | gep 51.58 |gepc 52.48 |dar  0.68 |
# scGPT - INFO - | epoch  10 | 300/708 batches | lr 0.00063 | ms/batch 63.24 | loss 104.04 | gep 51.35 |gepc 52.01 |dar  0.68 |
# scGPT - INFO - | epoch  10 | 400/708 batches | lr 0.00063 | ms/batch 63.23 | loss 106.96 | gep 52.77 |gepc 53.49 |dar  0.71 |
# scGPT - INFO - | epoch  10 | 500/708 batches | lr 0.00063 | ms/batch 63.15 | loss 103.88 | gep 51.35 |gepc 51.85 |dar  0.68 |
# scGPT - INFO - | epoch  10 | 600/708 batches | lr 0.00063 | ms/batch 63.25 | loss 103.06 | gep 50.83 |gepc 51.53 |dar  0.70 |
# scGPT - INFO - | epoch  10 | 700/708 batches | lr 0.00063 | ms/batch 63.91 | loss 103.54 | gep 51.20 |gepc 51.63 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  10 | time: 46.70s | valid loss 51.5813 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 51.5813
# scGPT - INFO - Saving model to save/dev_BMMC-May09-09-42
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████| 787/787 [00:15<00:00, 52.29it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.727787
# ARI_cluster/label          0.835278
# ASW_label                  0.672033
# ASW_label/batch            0.802395
# PCR_batch                  0.227716
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.894080
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6720, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.2277, ASW (batch): 0.8024, graph connectivity: 0.8941, graph iLISI: nan
# random masking at epoch  11, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  11 | 100/708 batches | lr 0.00060 | ms/batch 64.12 | loss 105.94 | gep 52.44 |gepc 52.82 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 200/708 batches | lr 0.00060 | ms/batch 63.33 | loss 102.31 | gep 50.43 |gepc 51.22 |dar  0.66 |
# scGPT - INFO - | epoch  11 | 300/708 batches | lr 0.00060 | ms/batch 63.86 | loss 102.98 | gep 50.80 |gepc 51.50 |dar  0.68 |
# scGPT - INFO - | epoch  11 | 400/708 batches | lr 0.00060 | ms/batch 63.75 | loss 104.19 | gep 51.40 |gepc 52.12 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 500/708 batches | lr 0.00060 | ms/batch 63.55 | loss 104.15 | gep 51.39 |gepc 52.08 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 600/708 batches | lr 0.00060 | ms/batch 63.51 | loss 104.47 | gep 51.56 |gepc 52.21 |dar  0.70 |
# scGPT - INFO - | epoch  11 | 700/708 batches | lr 0.00060 | ms/batch 63.58 | loss 103.48 | gep 51.05 |gepc 51.71 |dar  0.73 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  11 | time: 46.88s | valid loss 53.5696 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  12, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  12 | 100/708 batches | lr 0.00057 | ms/batch 63.79 | loss 104.38 | gep 51.45 |gepc 52.27 |dar  0.65 |
# scGPT - INFO - | epoch  12 | 200/708 batches | lr 0.00057 | ms/batch 63.29 | loss 102.96 | gep 50.79 |gepc 51.49 |dar  0.68 |
# scGPT - INFO - | epoch  12 | 300/708 batches | lr 0.00057 | ms/batch 63.76 | loss 102.21 | gep 50.47 |gepc 51.05 |dar  0.69 |
# scGPT - INFO - | epoch  12 | 400/708 batches | lr 0.00057 | ms/batch 63.34 | loss 102.81 | gep 50.78 |gepc 51.31 |dar  0.72 |
# scGPT - INFO - | epoch  12 | 500/708 batches | lr 0.00057 | ms/batch 63.32 | loss 103.38 | gep 50.96 |gepc 51.73 |dar  0.70 |
# scGPT - INFO - | epoch  12 | 600/708 batches | lr 0.00057 | ms/batch 63.21 | loss 103.29 | gep 51.01 |gepc 51.61 |dar  0.66 |
# scGPT - INFO - | epoch  12 | 700/708 batches | lr 0.00057 | ms/batch 63.40 | loss 103.78 | gep 51.09 |gepc 51.99 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  12 | time: 46.71s | valid loss 52.3673 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  13, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  13 | 100/708 batches | lr 0.00054 | ms/batch 63.92 | loss 103.97 | gep 51.25 |gepc 52.03 |dar  0.70 |
# scGPT - INFO - | epoch  13 | 200/708 batches | lr 0.00054 | ms/batch 63.50 | loss 100.67 | gep 49.78 |gepc 50.19 |dar  0.70 |
# scGPT - INFO - | epoch  13 | 300/708 batches | lr 0.00054 | ms/batch 63.24 | loss 102.57 | gep 50.55 |gepc 51.32 |dar  0.69 |
# scGPT - INFO - | epoch  13 | 400/708 batches | lr 0.00054 | ms/batch 63.30 | loss 102.40 | gep 50.46 |gepc 51.26 |dar  0.68 |
# scGPT - INFO - | epoch  13 | 500/708 batches | lr 0.00054 | ms/batch 63.37 | loss 101.99 | gep 50.23 |gepc 51.09 |dar  0.66 |
# scGPT - INFO - | epoch  13 | 600/708 batches | lr 0.00054 | ms/batch 63.69 | loss 103.58 | gep 51.03 |gepc 51.89 |dar  0.66 |
# scGPT - INFO - | epoch  13 | 700/708 batches | lr 0.00054 | ms/batch 63.48 | loss 102.38 | gep 50.43 |gepc 51.27 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  13 | time: 46.75s | valid loss 52.2386 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  14, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  14 | 100/708 batches | lr 0.00051 | ms/batch 64.19 | loss 102.94 | gep 50.78 |gepc 51.50 |dar  0.66 |
# scGPT - INFO - | epoch  14 | 200/708 batches | lr 0.00051 | ms/batch 63.57 | loss 101.45 | gep 49.97 |gepc 50.82 |dar  0.67 |
# scGPT - INFO - | epoch  14 | 300/708 batches | lr 0.00051 | ms/batch 63.28 | loss 101.70 | gep 50.14 |gepc 50.86 |dar  0.71 |
# scGPT - INFO - | epoch  14 | 400/708 batches | lr 0.00051 | ms/batch 63.36 | loss 101.47 | gep 50.08 |gepc 50.73 |dar  0.66 |
# scGPT - INFO - | epoch  14 | 500/708 batches | lr 0.00051 | ms/batch 63.42 | loss 101.18 | gep 49.93 |gepc 50.56 |dar  0.69 |
# scGPT - INFO - | epoch  14 | 600/708 batches | lr 0.00051 | ms/batch 63.23 | loss 103.20 | gep 50.95 |gepc 51.60 |dar  0.65 |
# scGPT - INFO - | epoch  14 | 700/708 batches | lr 0.00051 | ms/batch 63.62 | loss 101.71 | gep 50.13 |gepc 50.91 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  14 | time: 46.77s | valid loss 50.6010 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.6010
# random masking at epoch  15, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  15 | 100/708 batches | lr 0.00049 | ms/batch 64.42 | loss 101.40 | gep 50.00 |gepc 50.72 |dar  0.68 |
# scGPT - INFO - | epoch  15 | 200/708 batches | lr 0.00049 | ms/batch 63.33 | loss 100.77 | gep 49.75 |gepc 50.35 |dar  0.66 |
# scGPT - INFO - | epoch  15 | 300/708 batches | lr 0.00049 | ms/batch 63.38 | loss 101.89 | gep 50.25 |gepc 50.95 |dar  0.69 |
# scGPT - INFO - | epoch  15 | 400/708 batches | lr 0.00049 | ms/batch 63.22 | loss 101.19 | gep 49.89 |gepc 50.66 |dar  0.65 |
# scGPT - INFO - | epoch  15 | 500/708 batches | lr 0.00049 | ms/batch 63.31 | loss 99.49 | gep 49.12 |gepc 49.69 |dar  0.68 |
# scGPT - INFO - | epoch  15 | 600/708 batches | lr 0.00049 | ms/batch 63.31 | loss 102.05 | gep 50.23 |gepc 51.15 |dar  0.66 |
# scGPT - INFO - | epoch  15 | 700/708 batches | lr 0.00049 | ms/batch 63.27 | loss 102.42 | gep 50.52 |gepc 51.19 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  15 | time: 46.72s | valid loss 50.8822 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-May09-09-42
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████| 787/787 [00:15<00:00, 52.28it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.765092
# ARI_cluster/label          0.916657
# ASW_label                  0.658455
# ASW_label/batch            0.827432
# PCR_batch                  0.281586
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.882917
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6585, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.2816, ASW (batch): 0.8274, graph connectivity: 0.8829, graph iLISI: nan
# random masking at epoch  16, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  16 | 100/708 batches | lr 0.00046 | ms/batch 64.39 | loss 102.21 | gep 50.34 |gepc 51.18 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 200/708 batches | lr 0.00046 | ms/batch 63.82 | loss 100.99 | gep 49.79 |gepc 50.55 |dar  0.65 |
# scGPT - INFO - | epoch  16 | 300/708 batches | lr 0.00046 | ms/batch 63.52 | loss 102.96 | gep 50.79 |gepc 51.49 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 400/708 batches | lr 0.00046 | ms/batch 64.25 | loss 100.26 | gep 49.39 |gepc 50.17 |dar  0.70 |
# scGPT - INFO - | epoch  16 | 500/708 batches | lr 0.00046 | ms/batch 63.22 | loss 99.98 | gep 49.30 |gepc 50.00 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 600/708 batches | lr 0.00046 | ms/batch 63.24 | loss 100.50 | gep 49.57 |gepc 50.25 |dar  0.68 |
# scGPT - INFO - | epoch  16 | 700/708 batches | lr 0.00046 | ms/batch 63.60 | loss 99.73 | gep 49.23 |gepc 49.82 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  16 | time: 46.92s | valid loss 51.7471 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  17, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  17 | 100/708 batches | lr 0.00044 | ms/batch 64.13 | loss 100.49 | gep 49.56 |gepc 50.29 |dar  0.64 |
# scGPT - INFO - | epoch  17 | 200/708 batches | lr 0.00044 | ms/batch 63.54 | loss 100.93 | gep 49.62 |gepc 50.63 |dar  0.68 |
# scGPT - INFO - | epoch  17 | 300/708 batches | lr 0.00044 | ms/batch 63.45 | loss 101.95 | gep 50.34 |gepc 50.98 |dar  0.63 |
# scGPT - INFO - | epoch  17 | 400/708 batches | lr 0.00044 | ms/batch 63.40 | loss 100.48 | gep 49.52 |gepc 50.27 |dar  0.69 |
# scGPT - INFO - | epoch  17 | 500/708 batches | lr 0.00044 | ms/batch 63.62 | loss 100.42 | gep 49.54 |gepc 50.19 |dar  0.69 |
# scGPT - INFO - | epoch  17 | 600/708 batches | lr 0.00044 | ms/batch 63.50 | loss 101.45 | gep 50.03 |gepc 50.72 |dar  0.69 |
# scGPT - INFO - | epoch  17 | 700/708 batches | lr 0.00044 | ms/batch 63.92 | loss 99.40 | gep 49.02 |gepc 49.68 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  17 | time: 46.85s | valid loss 50.3802 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.3802
# random masking at epoch  18, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  18 | 100/708 batches | lr 0.00042 | ms/batch 64.04 | loss 98.29 | gep 48.40 |gepc 49.17 |dar  0.71 |
# scGPT - INFO - | epoch  18 | 200/708 batches | lr 0.00042 | ms/batch 63.19 | loss 99.53 | gep 49.06 |gepc 49.77 |dar  0.70 |
# scGPT - INFO - | epoch  18 | 300/708 batches | lr 0.00042 | ms/batch 63.43 | loss 100.42 | gep 49.51 |gepc 50.26 |dar  0.65 |
# scGPT - INFO - | epoch  18 | 400/708 batches | lr 0.00042 | ms/batch 63.35 | loss 100.75 | gep 49.70 |gepc 50.40 |dar  0.64 |
# scGPT - INFO - | epoch  18 | 500/708 batches | lr 0.00042 | ms/batch 63.51 | loss 100.03 | gep 49.36 |gepc 50.00 |dar  0.66 |
# scGPT - INFO - | epoch  18 | 600/708 batches | lr 0.00042 | ms/batch 63.42 | loss 100.79 | gep 49.68 |gepc 50.41 |dar  0.71 |
# scGPT - INFO - | epoch  18 | 700/708 batches | lr 0.00042 | ms/batch 63.51 | loss 98.53 | gep 48.57 |gepc 49.30 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  18 | time: 46.76s | valid loss 50.5781 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  19, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  19 | 100/708 batches | lr 0.00040 | ms/batch 64.09 | loss 100.50 | gep 49.49 |gepc 50.30 |dar  0.72 |
# scGPT - INFO - | epoch  19 | 200/708 batches | lr 0.00040 | ms/batch 63.40 | loss 100.15 | gep 49.36 |gepc 50.16 |dar  0.64 |
# scGPT - INFO - | epoch  19 | 300/708 batches | lr 0.00040 | ms/batch 64.11 | loss 99.34 | gep 49.00 |gepc 49.70 |dar  0.65 |
# scGPT - INFO - | epoch  19 | 400/708 batches | lr 0.00040 | ms/batch 63.45 | loss 99.40 | gep 49.04 |gepc 49.67 |dar  0.69 |
# scGPT - INFO - | epoch  19 | 500/708 batches | lr 0.00040 | ms/batch 63.41 | loss 98.46 | gep 48.57 |gepc 49.22 |dar  0.68 |
# scGPT - INFO - | epoch  19 | 600/708 batches | lr 0.00040 | ms/batch 63.42 | loss 99.92 | gep 49.22 |gepc 49.99 |dar  0.71 |
# scGPT - INFO - | epoch  19 | 700/708 batches | lr 0.00040 | ms/batch 63.41 | loss 99.71 | gep 49.20 |gepc 49.81 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  19 | time: 46.84s | valid loss 50.8009 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  20, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  20 | 100/708 batches | lr 0.00038 | ms/batch 64.29 | loss 100.99 | gep 49.81 |gepc 50.50 |dar  0.68 |
# scGPT - INFO - | epoch  20 | 200/708 batches | lr 0.00038 | ms/batch 63.43 | loss 97.83 | gep 48.30 |gepc 48.84 |dar  0.69 |
# scGPT - INFO - | epoch  20 | 300/708 batches | lr 0.00038 | ms/batch 63.57 | loss 99.45 | gep 49.04 |gepc 49.73 |dar  0.67 |
# scGPT - INFO - | epoch  20 | 400/708 batches | lr 0.00038 | ms/batch 63.37 | loss 98.81 | gep 48.75 |gepc 49.39 |dar  0.67 |
# scGPT - INFO - | epoch  20 | 500/708 batches | lr 0.00038 | ms/batch 63.22 | loss 99.04 | gep 48.79 |gepc 49.55 |dar  0.71 |
# scGPT - INFO - | epoch  20 | 600/708 batches | lr 0.00038 | ms/batch 64.25 | loss 99.31 | gep 48.99 |gepc 49.66 |dar  0.66 |
# scGPT - INFO - | epoch  20 | 700/708 batches | lr 0.00038 | ms/batch 63.40 | loss 100.26 | gep 49.44 |gepc 50.18 |dar  0.64 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  20 | time: 46.86s | valid loss 50.2237 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.2237
# scGPT - INFO - Saving model to save/dev_BMMC-May09-09-42
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████| 787/787 [00:15<00:00, 52.15it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.782597
# ARI_cluster/label          0.939751
# ASW_label                  0.645715
# ASW_label/batch            0.864573
# PCR_batch                  0.415462
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.912287
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6457, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.4155, ASW (batch): 0.8646, graph connectivity: 0.9123, graph iLISI: nan
# random masking at epoch  21, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  21 | 100/708 batches | lr 0.00036 | ms/batch 64.10 | loss 99.27 | gep 48.89 |gepc 49.70 |dar  0.68 |
# scGPT - INFO - | epoch  21 | 200/708 batches | lr 0.00036 | ms/batch 63.44 | loss 98.26 | gep 48.49 |gepc 49.10 |dar  0.66 |
# scGPT - INFO - | epoch  21 | 300/708 batches | lr 0.00036 | ms/batch 63.43 | loss 98.63 | gep 48.66 |gepc 49.33 |dar  0.63 |
# scGPT - INFO - | epoch  21 | 400/708 batches | lr 0.00036 | ms/batch 63.28 | loss 99.45 | gep 49.02 |gepc 49.75 |dar  0.68 |
# scGPT - INFO - | epoch  21 | 500/708 batches | lr 0.00036 | ms/batch 63.26 | loss 97.54 | gep 48.13 |gepc 48.76 |dar  0.65 |
# scGPT - INFO - | epoch  21 | 600/708 batches | lr 0.00036 | ms/batch 63.47 | loss 97.69 | gep 48.14 |gepc 48.86 |dar  0.69 |
# scGPT - INFO - | epoch  21 | 700/708 batches | lr 0.00036 | ms/batch 63.19 | loss 98.33 | gep 48.53 |gepc 49.12 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  21 | time: 46.72s | valid loss 50.0723 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.0723
# random masking at epoch  22, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  22 | 100/708 batches | lr 0.00034 | ms/batch 63.97 | loss 98.99 | gep 48.78 |gepc 49.52 |dar  0.69 |
# scGPT - INFO - | epoch  22 | 200/708 batches | lr 0.00034 | ms/batch 63.77 | loss 98.26 | gep 48.44 |gepc 49.15 |dar  0.67 |
# scGPT - INFO - | epoch  22 | 300/708 batches | lr 0.00034 | ms/batch 63.36 | loss 98.30 | gep 48.50 |gepc 49.14 |dar  0.66 |
# scGPT - INFO - | epoch  22 | 400/708 batches | lr 0.00034 | ms/batch 63.57 | loss 97.99 | gep 48.34 |gepc 48.97 |dar  0.69 |
# scGPT - INFO - | epoch  22 | 500/708 batches | lr 0.00034 | ms/batch 63.34 | loss 97.00 | gep 47.83 |gepc 48.51 |dar  0.67 |
# scGPT - INFO - | epoch  22 | 600/708 batches | lr 0.00034 | ms/batch 63.48 | loss 98.08 | gep 48.40 |gepc 49.03 |dar  0.65 |
# scGPT - INFO - | epoch  22 | 700/708 batches | lr 0.00034 | ms/batch 63.63 | loss 98.97 | gep 48.81 |gepc 49.49 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  22 | time: 46.82s | valid loss 50.9635 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  23, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  23 | 100/708 batches | lr 0.00032 | ms/batch 64.08 | loss 98.82 | gep 48.71 |gepc 49.39 |dar  0.71 |
# scGPT - INFO - | epoch  23 | 200/708 batches | lr 0.00032 | ms/batch 63.43 | loss 97.68 | gep 48.14 |gepc 48.86 |dar  0.68 |
# scGPT - INFO - | epoch  23 | 300/708 batches | lr 0.00032 | ms/batch 63.37 | loss 98.36 | gep 48.58 |gepc 49.13 |dar  0.65 |
# scGPT - INFO - | epoch  23 | 400/708 batches | lr 0.00032 | ms/batch 63.29 | loss 97.85 | gep 48.20 |gepc 48.99 |dar  0.67 |
# scGPT - INFO - | epoch  23 | 500/708 batches | lr 0.00032 | ms/batch 63.79 | loss 97.89 | gep 48.27 |gepc 48.95 |dar  0.67 |
# scGPT - INFO - | epoch  23 | 600/708 batches | lr 0.00032 | ms/batch 63.36 | loss 98.24 | gep 48.39 |gepc 49.19 |dar  0.66 |
# scGPT - INFO - | epoch  23 | 700/708 batches | lr 0.00032 | ms/batch 63.32 | loss 97.54 | gep 48.06 |gepc 48.78 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  23 | time: 46.77s | valid loss 49.9292 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 49.9292
# random masking at epoch  24, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  24 | 100/708 batches | lr 0.00031 | ms/batch 64.01 | loss 97.55 | gep 48.04 |gepc 48.85 |dar  0.66 |
# scGPT - INFO - | epoch  24 | 200/708 batches | lr 0.00031 | ms/batch 63.47 | loss 99.58 | gep 49.06 |gepc 49.83 |dar  0.69 |
# scGPT - INFO - | epoch  24 | 300/708 batches | lr 0.00031 | ms/batch 63.44 | loss 96.62 | gep 47.67 |gepc 48.29 |dar  0.66 |
# scGPT - INFO - | epoch  24 | 400/708 batches | lr 0.00031 | ms/batch 63.45 | loss 97.12 | gep 47.99 |gepc 48.49 |dar  0.65 |
# scGPT - INFO - | epoch  24 | 500/708 batches | lr 0.00031 | ms/batch 63.44 | loss 96.85 | gep 47.80 |gepc 48.38 |dar  0.67 |
# scGPT - INFO - | epoch  24 | 600/708 batches | lr 0.00031 | ms/batch 63.25 | loss 97.39 | gep 48.04 |gepc 48.68 |dar  0.67 |
# scGPT - INFO - | epoch  24 | 700/708 batches | lr 0.00031 | ms/batch 63.37 | loss 98.48 | gep 48.53 |gepc 49.29 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  24 | time: 46.74s | valid loss 50.0483 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  25, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  25 | 100/708 batches | lr 0.00029 | ms/batch 64.49 | loss 98.56 | gep 48.62 |gepc 49.23 |dar  0.70 |
# scGPT - INFO - | epoch  25 | 200/708 batches | lr 0.00029 | ms/batch 63.21 | loss 97.25 | gep 47.91 |gepc 48.64 |dar  0.70 |
# scGPT - INFO - | epoch  25 | 300/708 batches | lr 0.00029 | ms/batch 63.20 | loss 96.53 | gep 47.58 |gepc 48.23 |dar  0.72 |
# scGPT - INFO - | epoch  25 | 400/708 batches | lr 0.00029 | ms/batch 63.38 | loss 96.22 | gep 47.46 |gepc 48.08 |dar  0.69 |
# scGPT - INFO - | epoch  25 | 500/708 batches | lr 0.00029 | ms/batch 63.60 | loss 96.92 | gep 47.73 |gepc 48.48 |dar  0.71 |
# scGPT - INFO - | epoch  25 | 600/708 batches | lr 0.00029 | ms/batch 63.49 | loss 97.42 | gep 48.09 |gepc 48.67 |dar  0.67 |
# scGPT - INFO - | epoch  25 | 700/708 batches | lr 0.00029 | ms/batch 63.38 | loss 97.77 | gep 48.21 |gepc 48.93 |dar  0.62 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  25 | time: 46.79s | valid loss 50.1084 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-May09-09-42
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|████████████████████████████████████████████████████████| 787/787 [00:15<00:00, 52.46it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.803919
# ARI_cluster/label          0.945597
# ASW_label                  0.640848
# ASW_label/batch            0.858911
# PCR_batch                  0.428710
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.910499
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6408, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.4287, ASW (batch): 0.8589, graph connectivity: 0.9105, graph iLISI: nan

# %%
# save the best model
torch.save(best_model.state_dict(), save_dir / "best_model.pt")

# %%
artifact = wandb.Artifact(f"best_model", type="model")
glob_str = os.path.join(save_dir, "best_model.pt")
artifact.add_file(glob_str)
run.log_artifact(artifact)

run.finish()
wandb.finish()
gc.collect()
# Out:
# VBox(children=(Label(value='45.765 MB of 45.765 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>▁▆▇██</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>test/ARI_cluster/label</td><td>▁▅▇██</td></tr><tr><td>test/ASW_label</td><td>▃█▅▂▁</td></tr><tr><td>test/ASW_label/batch</td><td>▁▁▄█▇</td></tr><tr><td>test/NMI_cluster/label</td><td>▁▅▆▇█</td></tr><tr><td>test/PCR_batch</td><td>▁▃▄██</td></tr><tr><td>test/avg_bio</td><td>▁▆▇██</td></tr><tr><td>test/best_model_epoch</td><td>▁▃▅▇█</td></tr><tr><td>test/graph_conn</td><td>▁▇▇██</td></tr><tr><td>train/dab</td><td>▇▇▆▅▇▅▅▆▃▂▂▃▇▂▄█▃▄▅▃▅▇▄█▂▂▃▁▄▁▃▅▂▅▂▂█▂▄▂</td></tr><tr><td>train/gep</td><td>███▂▂▂▂▂▁▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>train/mvc</td><td>▆▇█▅▃▂▄▅▂▃▄▃▃▃▁▂▄▂▃▃▂▂▃▃▂▃▂▃▁▂▃▃▁▂▂▁▂▂▁▁</td></tr><tr><td>valid/loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>0.79679</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>test/ARI_cluster/label</td><td>0.9456</td></tr><tr><td>test/ASW_label</td><td>0.64085</td></tr><tr><td>test/ASW_label/batch</td><td>0.85891</td></tr><tr><td>test/NMI_cluster/label</td><td>0.80392</td></tr><tr><td>test/PCR_batch</td><td>0.42871</td></tr><tr><td>test/best_model_epoch</td><td>23</td></tr><tr><td>test/graph_conn</td><td>0.9105</td></tr><tr><td>train/dab</td><td>0.44954</td></tr><tr><td>train/gep</td><td>59.49837</td></tr><tr><td>train/mvc</td><td>61.17939</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lilac-gorge-11</strong> at: <a href='https://wandb.ai/kuzmina7748/scGPT/runs/j3gn7n7v' target="_blank">https://wandb.ai/kuzmina7748/scGPT/runs/j3gn7n7v</a><br/>Synced 6 W&B file(s), 10 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240509_094211-j3gn7n7v/logs</code>
# 65140
